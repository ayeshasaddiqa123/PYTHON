# %%
a = 2+1j
print(a.real)
print(a.imag)
print(a.conjugate())

# making complex numbers using function
b = complex(2,1)
print(b)
# Out:
# 2.0
# 1.0
# (2-1j)
# (2+1j)

# %%
str = "BrokenPipeError"
print(str.capitalize())
print(str.upper())
print(str.lower())
print(str.title())
print(str.swapcase())
print(str.isupper())
print(str.islower())
print(str.isspace())
print(str.isalnum())
# Out:
# Brokenpipeerror
# BROKENPIPEERROR
# brokenpipeerror
# Brokenpipeerror
# bROKENpIPEeRROR
# False
# False
# False
# True

# %%
print(str.isalpha())
print(str.isdigit())
print(str.isdecimal())
print(str.isprintable())
print(str.find("en"))
print(str.replace('B','t'))
print(str.isalpha())
# Out:
# True
# False
# False
# True
# 4
# trokenPipeError
# True

# %%
print(str.rfind('or'))
print(len(str))
print(str.split("en"))
print(str.rsplit("or"))
print(str.count("en"))
# Out:
# 13
# 15
# ['Brok', 'PipeError']
# ['BrokenPipeErr', '']
# 1

# %%
print(str.encode())
print(str.casefold())
print(str.zfill(19))
print(str.center(19))
# Out:
# b'BrokenPipeError'
# brokenpipeerror
# 0000BrokenPipeError
#   BrokenPipeError

# %%
print(str.ljust(19))
print(str.rjust(19))
# Out:
# BrokenPipeError
#     BrokenPipeError

# %%
print(str.partition("ip"))
print(str.rpartition("ip"))
print(str.join(("the","is")))
print(str.join(("theis")))
print(str.join(("dt",)))
# Out:
# ('BrokenP', 'ip', 'eError')
# ('BrokenP', 'ip', 'eError')
# theBrokenPipeErroris
# tBrokenPipeErrorhBrokenPipeErroreBrokenPipeErroriBrokenPipeErrors
# dt
