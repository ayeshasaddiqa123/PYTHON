# %%
from pathlib import Path

# %%
curr = Path.cwd()

# %%
curr
# Out:
# WindowsPath('d:/PYTHON/PYTHON_LIBRARIES')

# %%
curr2 = Path('.')
curr2
# Out:
# WindowsPath('.')

# %%
curr == curr2
# Out:
# False

# %%
curr.samefile(curr2)
# Out:
# True

# %%
Path.home()
# Out:
# WindowsPath('C:/Users/User')

# %%
with open('test.txt' , 'w') as f :
    f.write("Test")

# %%
file = Path('test.txt')
file
# Out:
# WindowsPath('test.txt')

# %%
file.absolute()
# Out:
# WindowsPath('d:/PYTHON/PYTHON_LIBRARIES/test.txt')

# %%
file_stat = file.stat()

file_stat
# Out:
# os.stat_result(st_mode=33206, st_ino=1125899906845576, st_dev=134125768704790000, st_nlink=1, st_uid=0, st_gid=0, st_size=4, st_atime=1785841804, st_mtime=1785841804, st_ctime=1785841804)

# %%
file_stat.st_size
# Out:
# 4

# %%
Path('test.txt').exists()
# Out:
# True

# %%
Path('test.txt').is_dir() , Path('D:\\').is_dir()
# Out:
# (False, True)

# %%
parts = ['dir1' , 'dir2' , 'test.txt']

# %%
Path('D:\\') . joinpath(*parts)
# Out:
# WindowsPath('D:/dir1/dir2/test.txt')

# %%
from pathlib import Path

file = Path('output.txt')
file.touch()

# %%
folder = Path('myfolder')
folder.mkdir()

# %%
# create a file inside a folder

new_file = folder / 'whatever.py'
new_file.touch()

# %%
python_file = Path('random_library.py')

python_file.write_text('import random')
# Out:
# 13

# %%
# Control multiple files.
