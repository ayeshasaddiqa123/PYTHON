# %%
 pip install seaborn
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# ...

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('ggplot')

# %%
df=pd.read_csv('students.csv')
df.head()
# Out:
#   student_id          name  class section  math_marks  science_marks  \
# 0     S10000  Aarav Sharma     10       A          85             78
# 1     S10001  Vivaan Verma     11       B          92             88
# 2     S10002  Aditya Patel     10       A          42             55
# 3     S10003  Vihaan Reddy     12       C          78             65
# 4     S10004   Arjun Singh      9       B          95             91
#
#    english_marks  hindi_marks  social_marks  attendance_percentage  ...  \
# 0             92           88            76                   92.5  ...
# 1             85           79            91                   88.0  ...
# 2             61           58            49                   75.5  ...
# 3             72           81            69                   81.0  ...
# 4             89           94            93                   96.5  ...
#
#    gender          address       city       phone    parent_name pass_status  \
# ...

# %%
df.shape
# Out:
# (50, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   student_id             50 non-null     object
#  1   name                   50 non-null     object
#  2   class                  50 non-null     int64
#  3   section                50 non-null     object
#  4   math_marks             50 non-null     int64
#  5   science_marks          50 non-null     int64
#  6   english_marks          50 non-null     int64
#  7   hindi_marks            50 non-null     int64
#  8   social_marks           50 non-null     int64
#  9   attendance_percentage  50 non-null     float64
#  10  age                    50 non-null     int64
#  11  gender                 50 non-null     object
#  12  address                50 non-null     object
#  13  city                   50 non-null     object
# ...
