# %%
import logging

# %%
logging.basicConfig(level = logging.DEBUG )

logging.debug("this is a debug msg")
logging.info("this is an info msg")
logging.warning("this is a warning msg")
logging.error("this is a error msg")
logging.critical("this is acritical msg")
# Out:
# DEBUG:root:this is a debug msg
# INFO:root:this is an info msg
# WARNING:root:this is a warning msg
# ERROR:root:this is a error msg
# CRITICAL:root:this is acritical msg

# %%
logger = logging.getLogger("mytestlogger")
logger.setLevel(logging.DEBUG)
handler = logging.StreamHandler()
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(name)s - %(message)s')

handler.setFormatter(formatter)
logger.addHandler(handler)

# %%
logger.info("my name is ............")
# Out:
# 2026-08-06 16:03:44,962 - INFO - mytestlogger - my name is ............
# 2026-08-06 16:03:44,962 - INFO - mytestlogger - my name is ............
# 2026-08-06 16:03:44,962 - INFO - mytestlogger - my name is ............
# INFO:mytestlogger:my name is ............

# %%
logging.FileHandler("my_test.log")
# Out:
# <FileHandler d:\PYTHON\PYTHON_LIBRARIES\my_test.log (NOTSET)>

# %%
logger.info("My name is sudhanshu")
# Out:
# 2026-08-06 16:03:45,005 - INFO - mytestlogger - My name is sudhanshu
# 2026-08-06 16:03:45,005 - INFO - mytestlogger - My name is sudhanshu
# 2026-08-06 16:03:45,005 - INFO - mytestlogger - My name is sudhanshu
# INFO:mytestlogger:My name is sudhanshu
